# %% [markdown]
# ## Comparing Housing Market "Hotness": Dallas vs Austin

# %%
# Import dependencies
import hvplot.pandas
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
import numpy as np

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the csv file
austin_dallas_housing_df = pd.read_csv("newdata.csv",encoding='utf-8')
austin_dallas_housing_df.head(10)
# Out:
#      City  State Month of Period End Median Sale Price Median Sale Price MoM   \
# 0  Austin  Texas              Feb-12             $190K                  5.60%
# 1  Austin  Texas              Mar-12             $200K                  5.10%
# 2  Austin  Texas              Apr-12             $205K                  2.70%
# 3  Austin  Texas              May-12             $210K                  2.40%
# 4  Austin  Texas              Jun-12             $214K                  2.00%
# 5  Austin  Texas              Jul-12             $210K                 -1.90%
# 6  Austin  Texas              Aug-12             $209K                 -0.50%
# 7  Austin  Texas              Sep-12             $197K                 -6.00%
# 8  Austin  Texas              Oct-12             $199K                  1.40%
# 9  Austin  Texas              Nov-12             $199K                  0.00%
#
#   Median Sale Price YoY  Homes Sold Homes Sold MoM  Homes Sold YoY   \
# 0                  2.20%      1,403          18.60%          16.60%
# 1                  8.70%      2,076          48.00%          18.60%
# 2                  7.90%      2,120           2.10%          14.80%
# 3                  9.10%      2,584          21.90%          25.10%
# 4                  8.70%      2,842          10.00%          21.00%
# 5                 10.20%      2,586          -9.00%          20.30%
# 6                  8.60%      2,585           0.00%          17.50%
# 7                  5.10%      1,991         -23.00%          10.90%
# 8                  5.40%      2,157           8.30%          38.70%
# 9                  7.70%      1,812         -16.00%          23.60%
#
#   New Listings  ... New Listings YoY  Inventory Inventory MoM   \
# 0        2,569  ...            10.40%     6,941          1.20%
# 1        3,400  ...            -3.00%     7,394          6.50%
# 2        3,379  ...             1.40%     7,698          4.10%
# 3        3,493  ...            11.80%     7,908          2.70%
# 4        3,396  ...             8.80%     8,152          3.10%
# 5        2,939  ...             7.20%     8,068         -1.00%
# 6        2,709  ...            15.80%     7,669         -4.90%
# 7        2,107  ...             1.50%     7,250         -5.50%
# 8        2,234  ...             6.90%     6,773         -6.60%
# 9        1,933  ...            10.40%     6,236         -7.90%
#
#    Inventory YoY  Days on Market  Days on Market MoM  Days on Market YoY  \
# 0         -21.50%             74                   0                 -18
# 1         -23.10%             58                 -16                 -26
# 2         -24.00%             39                 -19                 -21
# 3         -22.50%             36                  -3                 -18
# 4         -20.30%             31                  -5                 -21
# 5         -18.70%             34                   3                 -21
# 6         -17.60%             38                   4                 -23
# 7         -16.50%             43                   5                 -20
# 8         -18.30%             50                   7                 -16
# 9         -18.60%             48                  -2                 -22
#
#    Average Sale To List Average Sale To List MoM  Average Sale To List YoY
# 0                96.70%                     0.40%                     0.10%
# 1                97.30%                     0.60%                     0.90%
# 2                97.70%                     0.40%                     1.00%
# 3                97.60%                     0.00%                     1.00%
# 4                97.80%                     0.20%                     1.10%
# 5                97.80%                    -0.10%                     0.90%
# 6                97.60%                    -0.10%                     1.00%
# 7                97.40%                    -0.20%                     0.90%
# 8                97.20%                    -0.20%                     0.50%
# 9                97.30%                     0.10%                     0.60%
#
# [10 rows x 21 columns]

# %%
#Show data counts
austin_dallas_housing_df.count()
# Out:
# City                         262
# State                        262
# Month of Period End          262
# Median Sale Price            262
# Median Sale Price MoM        262
# Median Sale Price YoY        262
# Homes Sold                   262
# Homes Sold MoM               262
# Homes Sold YoY               262
# New Listings                 262
# New Listings MoM             262
# New Listings YoY             262
# Inventory                    262
# Inventory MoM                262
#  Inventory YoY               262
# Days on Market               262
# Days on Market MoM           262
# Days on Market YoY           262
# Average Sale To List         262
# Average Sale To List MoM     262
# Average Sale To List YoY     262
# dtype: int64

# %%
#Separating Austin data to new data frame
austin_data = austin_dallas_housing_df.loc[austin_dallas_housing_df["City"] == "Austin"]
austin_data
# Out:
#        City  State Month of Period End Median Sale Price  \
# 0    Austin  Texas              Feb-12             $190K
# 1    Austin  Texas              Mar-12             $200K
# 2    Austin  Texas              Apr-12             $205K
# 3    Austin  Texas              May-12             $210K
# 4    Austin  Texas              Jun-12             $214K
# ..      ...    ...                 ...               ...
# 126  Austin  Texas              Aug-22             $500K
# 127  Austin  Texas              Sep-22             $475K
# 128  Austin  Texas              Oct-22             $475K
# 129  Austin  Texas              Nov-22             $470K
# 130  Austin  Texas              Dec-22             $458K
#
#     Median Sale Price MoM  Median Sale Price YoY  Homes Sold Homes Sold MoM   \
# 0                    5.60%                  2.20%      1,403          18.60%
# 1                    5.10%                  8.70%      2,076          48.00%
# 2                    2.70%                  7.90%      2,120           2.10%
# 3                    2.40%                  9.10%      2,584          21.90%
# 4                    2.00%                  8.70%      2,842          10.00%
# ..                     ...                    ...        ...             ...
# 126                 -3.80%                  5.50%      2,872           3.10%
# 127                 -5.00%                  5.60%      2,880           0.30%
# 128                  0.00%                  3.70%      2,235         -22.40%
# 129                 -1.10%                 -0.20%      1,986         -11.10%
# 130                 -2.50%                 -3.60%      2,382          19.90%
#
#     Homes Sold YoY  New Listings  ... New Listings YoY  Inventory  \
# 0            16.60%        2,569  ...            10.40%     6,941
# 1            18.60%        3,400  ...            -3.00%     7,394
# 2            14.80%        3,379  ...             1.40%     7,698
# 3            25.10%        3,493  ...            11.80%     7,908
# 4            21.00%        3,396  ...             8.80%     8,152
# ..              ...          ...  ...               ...       ...
# 126         -24.00%        3,672  ...           -14.90%    10,739
# 127         -21.10%        3,528  ...           -11.50%    10,827
# 128         -29.60%        2,739  ...           -26.10%    10,291
# 129         -38.30%        2,015  ...           -30.50%     9,132
# 130         -33.90%        1,435  ...           -31.00%     7,376
#
#     Inventory MoM   Inventory YoY  Days on Market  Days on Market MoM  \
# 0            1.20%         -21.50%             74                   0
# 1            6.50%         -23.10%             58                 -16
# 2            4.10%         -24.00%             39                 -19
# 3            2.70%         -22.50%             36                  -3
# 4            3.10%         -20.30%             31                  -5
# ..             ...             ...            ...                 ...
# 126         -0.20%          77.90%             40                   6
# 127          0.80%          77.30%             47                   7
# 128         -5.00%          70.30%             53                   6
# 129        -11.30%          77.30%             61                   8
# 130        -19.20%          95.20%             70                   9
#
#      Days on Market YoY  Average Sale To List Average Sale To List MoM   \
# 0                   -18                96.70%                     0.40%
# 1                   -26                97.30%                     0.60%
# 2                   -21                97.70%                     0.40%
# 3                   -18                97.60%                     0.00%
# 4                   -21                97.80%                     0.20%
# ..                  ...                   ...                       ...
# 126                  10                98.90%                    -1.30%
# 127                  15                98.30%                    -0.60%
# 128                  19                97.30%                    -1.00%
# 129                  26                96.50%                    -0.90%
# 130                  35                96.10%                    -0.40%
#
#     Average Sale To List YoY
# 0                       0.10%
# 1                       0.90%
# 2                       1.00%
# 3                       1.00%
# 4                       1.10%
# ..                        ...
# 126                    -5.10%
# 127                    -3.90%
# 128                    -4.40%
# 129                    -4.80%
# 130                    -5.30%
#
# [131 rows x 21 columns]

# %%
#Separating Dallas information to new data frame
dallas_data = austin_dallas_housing_df.loc[austin_dallas_housing_df["City"] == "Dallas"]
dallas_data
# Out:
#        City  State Month of Period End Median Sale Price  \
# 131  Dallas  Texas              Feb-12             $160K
# 132  Dallas  Texas              Mar-12             $168K
# 133  Dallas  Texas              Apr-12             $169K
# 134  Dallas  Texas              May-12             $178K
# 135  Dallas  Texas              Jun-12             $180K
# ..      ...    ...                 ...               ...
# 257  Dallas  Texas              Aug-22             $430K
# 258  Dallas  Texas              Sep-22             $420K
# 259  Dallas  Texas              Oct-22             $420K
# 260  Dallas  Texas              Nov-22             $410K
# 261  Dallas  Texas              Dec-22             $402K
#
#     Median Sale Price MoM  Median Sale Price YoY  Homes Sold Homes Sold MoM   \
# 131                  4.70%                  1.30%      2,998          20.80%
# 132                  4.70%                  8.80%      3,979          32.70%
# 133                  0.90%                  5.80%      4,202           5.60%
# 134                  5.30%                  7.80%      4,919          17.10%
# 135                  1.20%                  8.40%      5,089           3.50%
# ..                     ...                    ...        ...             ...
# 257                 -1.10%                 13.90%      6,128           6.90%
# 258                 -2.30%                 12.00%      5,450         -11.10%
# 259                  0.00%                 11.10%      4,573         -16.10%
# 260                 -2.40%                  8.30%      4,064         -11.10%
# 261                 -2.00%                  5.40%      4,324           6.40%
#
#     Homes Sold YoY  New Listings  ... New Listings YoY  Inventory  \
# 131          22.80%        5,533  ...            15.70%    17,066
# 132          12.60%        6,607  ...            -5.30%    17,862
# 133          13.70%        6,303  ...            -4.90%    18,194
# 134          23.10%        6,437  ...             8.50%    18,225
# 135          13.80%        6,227  ...             0.10%    18,412
# ..              ...          ...  ...               ...       ...
# 257         -11.50%        6,879  ...            -7.10%    13,765
# 258         -17.90%        6,459  ...            -4.70%    13,887
# 259         -26.30%        5,564  ...            -9.30%    13,714
# 260         -30.50%        4,439  ...           -14.10%    12,697
# 261         -31.20%        3,162  ...           -23.50%    10,137
#
#     Inventory MoM   Inventory YoY  Days on Market  Days on Market MoM  \
# 131          4.20%         -22.90%             83                  -2
# 132          4.70%         -22.80%             63                 -20
# 133          1.90%         -23.60%             49                 -14
# 134          0.20%         -22.90%             49                   0
# 135          1.00%         -22.00%             49                   0
# ..             ...             ...            ...                 ...
# 257         -2.70%          47.50%             25                   6
# 258          0.90%          54.60%             32                   7
# 259         -1.20%          67.80%             33                   1
# 260         -7.40%          83.90%             37                   4
# 261        -20.20%          83.80%             45                   8
#
#      Days on Market YoY  Average Sale To List Average Sale To List MoM   \
# 131                 -15                96.40%                     0.20%
# 132                 -24                96.60%                     0.30%
# 133                 -23                97.00%                     0.40%
# 134                 -21                97.10%                     0.10%
# 135                 -21                97.40%                     0.30%
# ..                  ...                   ...                       ...
# 257                   7                99.70%                    -1.80%
# 258                  11                98.70%                    -1.00%
# 259                  11                98.50%                    -0.20%
# 260                  16                97.90%                    -0.60%
# 261                  24                97.50%                    -0.40%
#
#     Average Sale To List YoY
# 131                     0.20%
# 132                     0.60%
# 133                     0.90%
# 134                     0.80%
# 135                     1.10%
# ..                        ...
# 257                    -2.70%
# 258                    -2.80%
# 259                    -2.80%
# 260                    -3.60%
# 261                    -3.90%
#
# [131 rows x 21 columns]

# %%
#Check data types for each column
austin_data.dtypes
# Out:
# City                         object
# State                        object
# Month of Period End          object
# Median Sale Price            object
# Median Sale Price MoM        object
# Median Sale Price YoY        object
# Homes Sold                   object
# Homes Sold MoM               object
# Homes Sold YoY               object
# New Listings                 object
# New Listings MoM             object
# New Listings YoY             object
# Inventory                    object
# Inventory MoM                object
#  Inventory YoY               object
# Days on Market                int64
# Days on Market MoM            int64
# Days on Market YoY            int64
# Average Sale To List         object
# Average Sale To List MoM     object
# Average Sale To List YoY     object
# dtype: object

# %%
#Get rid of '$' and 'K' from Median Price column. Change column type to a float to prepare for graphing.
austin_data["Median Sale Price"] = austin_data["Median Sale Price"].str.replace("$", "")
austin_data["Median Sale Price"] = austin_data["Median Sale Price"].str.replace("K", "")
austin_data["Median Sale Price"] = austin_data["Median Sale Price"].astype(float)
austin_data.head()
# Out:
#      City  State Month of Period End  Median Sale Price  \
# 0  Austin  Texas              Feb-12              190.0
# 1  Austin  Texas              Mar-12              200.0
# 2  Austin  Texas              Apr-12              205.0
# 3  Austin  Texas              May-12              210.0
# 4  Austin  Texas              Jun-12              214.0
#
#   Median Sale Price MoM  Median Sale Price YoY  Homes Sold Homes Sold MoM   \
# 0                  5.60%                  2.20%      1,403          18.60%
# 1                  5.10%                  8.70%      2,076          48.00%
# 2                  2.70%                  7.90%      2,120           2.10%
# 3                  2.40%                  9.10%      2,584          21.90%
# 4                  2.00%                  8.70%      2,842          10.00%
#
#   Homes Sold YoY  New Listings  ... New Listings YoY  Inventory  \
# 0          16.60%        2,569  ...            10.40%     6,941
# 1          18.60%        3,400  ...            -3.00%     7,394
# 2          14.80%        3,379  ...             1.40%     7,698
# 3          25.10%        3,493  ...            11.80%     7,908
# 4          21.00%        3,396  ...             8.80%     8,152
#
#   Inventory MoM   Inventory YoY  Days on Market  Days on Market MoM  \
# 0          1.20%         -21.50%             74                   0
# 1          6.50%         -23.10%             58                 -16
# 2          4.10%         -24.00%             39                 -19
# 3          2.70%         -22.50%             36                  -3
# 4          3.10%         -20.30%             31                  -5
#
#    Days on Market YoY  Average Sale To List Average Sale To List MoM   \
# 0                 -18                96.70%                     0.40%
# 1                 -26                97.30%                     0.60%
# 2                 -21                97.70%                     0.40%
# 3                 -18                97.60%                     0.00%
# 4                 -21                97.80%                     0.20%
#
#   Average Sale To List YoY
# 0                     0.10%
# 1                     0.90%
# 2                     1.00%
# 3                     1.00%
# 4                     1.10%
#
# [5 rows x 21 columns]

# %%
#Get rid of '$' and 'K' from Median Price column. Change column type to a float to prepare for graphing.
dallas_data["Median Sale Price"] = dallas_data["Median Sale Price"].str.replace("$", "")
dallas_data["Median Sale Price"] = dallas_data["Median Sale Price"].str.replace("K", "")
dallas_data["Median Sale Price"] = dallas_data["Median Sale Price"].astype(float)
dallas_data.head()
# Out:
#        City  State Month of Period End  Median Sale Price  \
# 131  Dallas  Texas              Feb-12              160.0
# 132  Dallas  Texas              Mar-12              168.0
# 133  Dallas  Texas              Apr-12              169.0
# 134  Dallas  Texas              May-12              178.0
# 135  Dallas  Texas              Jun-12              180.0
#
#     Median Sale Price MoM  Median Sale Price YoY  Homes Sold Homes Sold MoM   \
# 131                  4.70%                  1.30%      2,998          20.80%
# 132                  4.70%                  8.80%      3,979          32.70%
# 133                  0.90%                  5.80%      4,202           5.60%
# 134                  5.30%                  7.80%      4,919          17.10%
# 135                  1.20%                  8.40%      5,089           3.50%
#
#     Homes Sold YoY  New Listings  ... New Listings YoY  Inventory  \
# 131          22.80%        5,533  ...            15.70%    17,066
# 132          12.60%        6,607  ...            -5.30%    17,862
# 133          13.70%        6,303  ...            -4.90%    18,194
# 134          23.10%        6,437  ...             8.50%    18,225
# 135          13.80%        6,227  ...             0.10%    18,412
#
#     Inventory MoM   Inventory YoY  Days on Market  Days on Market MoM  \
# 131          4.20%         -22.90%             83                  -2
# 132          4.70%         -22.80%             63                 -20
# 133          1.90%         -23.60%             49                 -14
# 134          0.20%         -22.90%             49                   0
# 135          1.00%         -22.00%             49                   0
#
#      Days on Market YoY  Average Sale To List Average Sale To List MoM   \
# 131                 -15                96.40%                     0.20%
# 132                 -24                96.60%                     0.30%
# 133                 -23                97.00%                     0.40%
# 134                 -21                97.10%                     0.10%
# 135                 -21                97.40%                     0.30%
#
#     Average Sale To List YoY
# 131                     0.20%
# 132                     0.60%
# 133                     0.90%
# 134                     0.80%
# 135                     1.10%
#
# [5 rows x 21 columns]

# %%
#Create data frame that contains only years 2018 to 2022 for graphing
austin_2018_2022 = austin_data.iloc[71:131]
austin_2018_2022
# Out:
#        City  State Month of Period End  Median Sale Price  \
# 71   Austin  Texas              Jan-18              291.0
# 72   Austin  Texas              Feb-18              295.0
# 73   Austin  Texas              Mar-18              300.0
# 74   Austin  Texas              Apr-18              315.0
# 75   Austin  Texas              May-18              318.0
# 76   Austin  Texas              Jun-18              321.0
# 77   Austin  Texas              Jul-18              315.0
# 78   Austin  Texas              Aug-18              317.0
# 79   Austin  Texas              Sep-18              300.0
# 80   Austin  Texas              Oct-18              305.0
# 81   Austin  Texas              Nov-18              300.0
# 82   Austin  Texas              Dec-18              304.0
# 83   Austin  Texas              Jan-19              295.0
# 84   Austin  Texas              Feb-19              294.0
# 85   Austin  Texas              Mar-19              305.0
# 86   Austin  Texas              Apr-19              319.0
# 87   Austin  Texas              May-19              329.0
# 88   Austin  Texas              Jun-19              329.0
# 89   Austin  Texas              Jul-19              320.0
# 90   Austin  Texas              Aug-19              320.0
# 96                   5.20%                 10.50%      2,596          27.90%
# 97                   2.30%                  9.10%      3,199          23.20%
# 98                  -2.10%                  2.10%      2,592         -19.00%
# 99                   1.30%                  0.30%      2,657           2.50%
# 100                  2.90%                  3.20%      4,007          50.80%
# 101                  3.70%                 10.00%      4,494          12.20%
# 102                 -0.60%                  9.40%      4,017         -10.60%
# 103                  1.40%                 10.90%      3,877          -3.50%
# 104                  3.50%                 13.10%      3,692          -4.80%
# 105                 -0.70%                 17.70%      3,390          -8.20%
# 106                  1.10%                 15.00%      3,708           9.40%
# 107                  0.30%                 19.70%      2,410         -35.00%
# 108                  7.40%                 22.20%      2,303          -4.40%
# 109                  7.50%                 28.40%      3,468          50.60%
# 110                  9.30%                 43.30%      3,578           3.20%
# 111                 -0.30%                 40.90%      3,881           8.50%
# 112                  3.40%                 41.70%      4,302          10.80%
# 113                  0.50%                 37.40%      3,968          -7.80%
# 114                 -1.90%                 35.50%      3,781          -4.70%
# 115                 -5.10%                 26.80%      3,652          -3.40%
# 116                  1.80%                 24.60%      3,176         -13.00%
# 117                  2.80%                 29.00%      3,218           1.30%
# 118                  0.90%                 28.70%      3,604          12.00%
# 119                  1.70%                 30.50%      2,277         -36.80%
# 120                  3.50%                 25.80%      2,551          12.00%
# 121                  4.20%                 22.00%      3,290          29.00%
# 122                  6.50%                 18.90%      3,226          -1.90%
# 123                 -0.90%                 18.30%      3,574          10.80%
# 124                 -2.80%                 11.20%      3,460          -3.20%
# 125                 -2.80%                  7.50%      2,785         -19.50%
# 126                 -3.80%                  5.50%      2,872           3.10%
# 127                 -5.00%                  5.60%      2,880           0.30%
# 128                  0.00%                  3.70%      2,235         -22.40%
# 129                 -1.10%                 -0.20%      1,986         -11.10%
# 130                 -2.50%                 -3.60%      2,382          19.90%
#
#     Homes Sold YoY  New Listings  ... New Listings YoY  Inventory  \
# 71            8.30%        2,523  ...            -4.90%     5,921
# 72            7.00%        3,149  ...             2.00%     6,172
# 73            9.10%        4,235  ...            -2.30%     6,850
# 74            6.60%        4,432  ...             5.20%     7,419
# 75            6.00%        4,686  ...             2.70%     8,135
# 76           -1.60%        4,328  ...            -3.40%     8,646
# 77            6.90%        3,855  ...            -1.70%     8,760
# 78            2.60%        3,850  ...            15.30%     8,959
# 79           -2.80%        2,856  ...             1.00%     8,809
# 80            4.30%        2,888  ...             1.80%     8,473
# 81            1.90%        2,388  ...            -0.70%     7,864
# 82           -9.70%        1,728  ...            -2.10%     6,806
# 83           -1.60%        2,882  ...            14.20%     6,710
# 84            5.90%        3,099  ...            -1.60%     6,717
# 85           -1.60%        4,135  ...            -2.40%     7,079
# 86           11.60%        4,320  ...            -2.50%     7,325
# 87            6.50%        4,765  ...             1.70%     7,988
# 88           -1.40%        4,272  ...            -1.30%     8,357
# 89            7.70%        3,970  ...             3.00%     8,330
# 90            6.40%        3,584  ...            -6.90%     8,109
# 91           14.60%        3,181  ...            11.40%     7,824
# 92           12.40%        3,181  ...            10.10%     7,470
# 93           11.00%        2,407  ...             0.80%     6,730
# 94           16.80%        1,787  ...             3.40%     5,836
# 95           11.70%        3,002  ...             4.20%     5,681
# 96            9.50%        3,278  ...             5.80%     5,683
# 97            7.30%        4,144  ...             0.20%     6,393
# 98          -22.50%        3,370  ...           -22.00%     6,885
# 99          -31.80%        3,965  ...           -16.80%     6,529
# 100           9.20%        4,048  ...            -5.20%     5,765
# 101          20.20%        4,596  ...            15.80%     5,806
# 102          12.40%        3,730  ...             4.10%     6,027
# 103          29.80%        3,368  ...             5.90%     6,212
# 104          26.20%        3,603  ...            13.30%     5,604
# 105          23.30%        2,659  ...            10.50%     4,724
# 106          18.70%        2,340  ...            30.90%     3,462
# 107          18.80%        2,796  ...            -6.90%     3,097
# 108         -11.30%        2,505  ...           -23.60%     3,049
# 109           8.40%        4,128  ...            -0.40%     3,541
# 110          38.00%        4,598  ...            36.40%     4,355
# 111          46.10%        4,338  ...             9.40%     4,558
# 112           7.40%        5,023  ...            24.10%     5,102
# 113         -11.70%        5,071  ...            10.30%     5,966
# 114          -5.90%        4,313  ...            15.60%     6,037
# 115          -5.80%        3,986  ...            18.30%     6,106
# 116         -14.00%        3,707  ...             2.90%     6,044
# 117          -5.10%        2,899  ...             9.00%     5,152
# 118          -2.80%        2,080  ...           -11.10%     3,778
# 119          -5.50%        2,528  ...            -9.60%     3,337
# 120          10.80%        2,775  ...            10.80%     3,322
# 121          -5.10%        4,103  ...            -0.60%     4,102
# 122          -9.80%        4,492  ...            -2.30%     5,294
# 123          -7.90%        5,089  ...            17.30%     6,830
# 124         -19.60%        5,834  ...            16.10%     9,259
# 125         -29.80%        4,818  ...            -5.00%    10,758
# 126         -24.00%        3,672  ...           -14.90%    10,739
# 127         -21.10%        3,528  ...           -11.50%    10,827
# 128         -29.60%        2,739  ...           -26.10%    10,291
# 129         -38.30%        2,015  ...           -30.50%     9,132
# 130         -33.90%        1,435  ...           -31.00%     7,376
#
#     Inventory MoM   Inventory YoY  Days on Market  Days on Market MoM  \
# 71          -5.70%           3.60%             48                  -5
# 72           4.20%           2.10%             52                   4
# 73          11.00%          -0.20%             31                 -21
# 74           8.30%          -0.90%             21                 -10
# 75           9.70%           1.80%             20                  -1
# 76           6.30%           0.00%             22                   2
# 77           1.30%          -1.90%             26                   4
# 78           2.30%           1.90%             32                   6
# 79          -1.70%           4.90%             35                   3
# 80          -3.80%           7.50%             43                   8
# 81          -7.20%           9.80%             48                   5
# 82         -13.50%           8.40%             51                   3
# 83          -1.40%          13.30%             56                   5
# 84           0.10%           8.80%             55                  -1
# 85           5.40%           3.30%             34                 -21
# 86           3.50%          -1.30%             21                 -13
# 87           9.10%          -1.80%             21                   0
# 88           4.60%          -3.30%             24                   3
# 89          -0.30%          -4.90%             25                   1
# 90          -2.70%          -9.50%             29                   4
# 91          -3.50%         -11.20%             33                   4
# 92          -4.50%         -11.80%             36                   3
# 93          -9.90%         -14.40%             40                   4
# 94         -13.30%         -14.30%             43                   3
# 95          -2.70%         -15.30%             47                   4
# 96           0.00%         -15.40%             42                  -5
# 97          12.50%          -9.70%             24                 -18
# 98           7.70%          -6.00%             16                  -8
# 99          -5.20%         -18.30%             23                   7
# 119                  -1               101.60%                     0.10%
# 120                   1               103.70%                     2.10%
# 121                  -4               105.40%                     1.70%
# 122                   0               106.20%                     0.80%
# 123                  -1               105.10%                    -1.10%
# 124                   2               102.50%                    -2.50%
# 125                   7               100.20%                    -2.40%
# 126                  10                98.90%                    -1.30%
# 127                  15                98.30%                    -0.60%
# 128                  19                97.30%                    -1.00%
# 129                  26                96.50%                    -0.90%
# 130                  35                96.10%                    -0.40%
#
#     Average Sale To List YoY
# 71                     -0.20%
# 72                     -0.10%
# 73                      0.00%
# 74                     -0.10%
# 75                      0.10%
# 76                      0.10%
# 77                      0.10%
# 78                      0.00%
# 79                      0.00%
# 80                      0.00%
# 81                      0.00%
# 82                      0.00%
# 83                     -0.10%
# 84                      0.10%
# 85                      0.10%
# 86                      0.10%
# 87                      0.20%
# 88                      0.10%
# 89                      0.20%
# 90                      0.50%
# 91                      0.40%
# 92                      0.50%
# 93                      0.50%
# 94                      0.40%
# 95                      0.50%
# 96                      0.70%
# 97                      0.80%
# 98                      0.60%
# 99                     -0.10%
# 100                     0.40%
# 101                     0.60%
# 102                     0.80%
# 103                     1.10%
# 104                     1.60%
# 105                     1.80%
# 106                     2.20%
# 107                     3.60%
# 108                     6.00%
# 109                     8.10%
# 110                    10.00%
# 111                     9.80%
# 112                     8.80%
# 113                     7.10%
# 114                     4.40%
# 115                     2.50%
# 116                     1.60%
# 117                     1.00%
# 118                     1.00%
# 119                    -0.20%
# 120                    -1.30%
# 121                    -2.00%
# 122                    -3.30%
# 123                    -3.70%
# 124                    -5.50%
# 125                    -6.40%
# 126                    -5.10%
# 127                    -3.90%
# 128                    -4.40%
# 129                    -4.80%
# 130                    -5.30%
#
# [60 rows x 21 columns]

# %%
#Create data frame that contains only years 2018 to 2022 for graphing
dallas_2018_2022 =dallas_data.iloc[71:131]
dallas_2018_2022
# Out:
#        City  State Month of Period End  Median Sale Price  \
# 202  Dallas  Texas              Jan-18              264.0
# 203  Dallas  Texas              Feb-18              280.0
# 204  Dallas  Texas              Mar-18              289.0
# 205  Dallas  Texas              Apr-18              285.0
# 206  Dallas  Texas              May-18              295.0
# 207  Dallas  Texas              Jun-18              300.0
# 208  Dallas  Texas              Jul-18              295.0
# 209  Dallas  Texas              Aug-18              289.0
# 210  Dallas  Texas              Sep-18              280.0
# 211  Dallas  Texas              Oct-18              275.0
# 212  Dallas  Texas              Nov-18              281.0
# 213  Dallas  Texas              Dec-18              285.0
# 214  Dallas  Texas              Jan-19              265.0
# 215  Dallas  Texas              Feb-19              277.0
# 216  Dallas  Texas              Mar-19              290.0
# 217  Dallas  Texas              Apr-19              294.0
# 218  Dallas  Texas              May-19              302.0
# 219  Dallas  Texas              Jun-19              305.0
# 220  Dallas  Texas              Jul-19              300.0
# 221  Dallas  Texas              Aug-19              294.0
# 222  Dallas  Texas              Sep-19              288.0
# 223  Dallas  Texas              Oct-19              288.0
# 224  Dallas  Texas              Nov-19              289.0
# 225  Dallas  Texas              Dec-19              296.0
# 226  Dallas  Texas              Jan-20              282.0
# 227  Dallas  Texas              Feb-20              287.0
# 230                  0.00%                 -0.60%      5,126           4.50%
# 231                  4.00%                  2.30%      7,359          43.60%
# 232                  2.60%                  6.70%      8,526          15.90%
# 233                  0.60%                  9.30%      7,395         -13.30%
# 234                 -0.60%                 11.10%      7,021          -5.10%
# 235                  0.90%                 12.20%      6,877          -2.10%
# 236                 -0.30%                 11.40%      5,848         -15.00%
# 237                 -0.60%                  8.10%      6,656          13.80%
# 238                 -1.60%                 11.70%      4,315         -35.20%
# 239                  4.90%                 15.20%      4,461           3.40%
# 240                  4.10%                 14.70%      6,029          35.10%
# 241                  4.70%                 20.00%      6,435           6.70%
# 242                  4.20%                 25.00%      6,747           4.80%
# 243                  1.30%                 21.80%      7,329           8.60%
# 244                  0.00%                 18.80%      6,978          -4.80%
# 245                 -0.70%                 17.20%      6,924          -0.80%
# 246                 -0.70%                 17.20%      6,639          -4.10%
# 247                  0.80%                 17.00%      6,201          -6.60%
# 248                  0.10%                 17.50%      5,844          -5.80%
# 249                  0.80%                 19.20%      6,282           7.50%
# 250                 -0.40%                 20.60%      4,205         -33.10%
# 251                  5.00%                 20.70%      4,494           6.90%
# 252                  5.30%                 22.10%      5,782          28.70%
# 253                  6.00%                 23.60%      5,799           0.30%
# 254                  4.00%                 23.50%      6,438          11.00%
# 255                 -1.60%                 19.90%      6,504           1.00%
# 256                 -4.50%                 14.50%      5,732         -11.90%
# 257                 -1.10%                 13.90%      6,128           6.90%
# 258                 -2.30%                 12.00%      5,450         -11.10%
# 259                  0.00%                 11.10%      4,573         -16.10%
# 260                 -2.40%                  8.30%      4,064         -11.10%
# 261                 -2.00%                  5.40%      4,324           6.40%
#
#     Homes Sold YoY  New Listings  ... New Listings YoY  Inventory  \
# 202           3.80%        5,839  ...             4.70%    12,167
# 203           5.00%        6,032  ...            -0.50%    12,585
# 204          -0.70%        7,967  ...            -2.40%    13,953
# 205           3.50%        8,477  ...            16.00%    15,214
# 206           1.50%        8,961  ...             6.20%    16,659
# 207          -1.10%        9,042  ...             4.80%    18,265
# 208           2.40%        7,951  ...             1.90%    18,622
# 209          -3.00%        7,424  ...             0.70%    18,648
# 210         -10.20%        6,193  ...            -3.20%    18,616
# 211          -3.10%        6,221  ...             3.50%    18,333
# 212         -11.40%        5,301  ...             5.60%    17,509
# 213         -11.30%        3,835  ...             1.80%    15,339
# 214         -11.60%        6,252  ...             7.10%    16,061
# 215          -4.00%        6,497  ...             7.70%    16,720
# 216          -3.00%        8,252  ...             3.60%    17,806
# 217           6.70%        8,812  ...             4.00%    18,903
# 218           6.00%        9,089  ...             1.40%    19,924
# 219          -6.10%        8,580  ...            -5.10%    20,883
# 220           8.00%        8,069  ...             1.50%    20,716
# 221           3.70%        7,393  ...            -0.40%    20,140
# 222          13.90%        6,690  ...             8.00%    19,593
# 223          11.30%        6,596  ...             6.00%    19,014
# 224           2.40%        5,197  ...            -2.00%    17,498
# 225          20.00%        3,983  ...             3.90%    14,899
# 226          23.10%        6,553  ...             4.80%    15,249
# 227          15.40%        6,958  ...             7.10%    15,762
# 228           5.30%        7,467  ...            -9.50%    15,702
# 229         -19.00%        6,201  ...           -29.60%    16,042
# 254                  -3               105.70%                    -0.40%
# 255                  -1               103.70%                    -2.00%
# 256                   1               101.50%                    -2.20%
# 257                   7                99.70%                    -1.80%
# 258                  11                98.70%                    -1.00%
# 259                  11                98.50%                    -0.20%
# 260                  16                97.90%                    -0.60%
# 261                  24                97.50%                    -0.40%
#
#     Average Sale To List YoY
# 202                    -0.30%
# 203                    -0.10%
# 204                    -0.40%
# 205                    -0.50%
# 206                    -0.50%
# 207                    -0.50%
# 208                    -0.60%
# 209                    -0.60%
# 210                    -0.30%
# 211                    -0.20%
# 212                    -0.40%
# 213                    -0.30%
# 214                    -0.40%
# 215                    -0.60%
# 216                    -0.60%
# 217                    -0.60%
# 218                    -0.60%
# 219                    -0.50%
# 220                    -0.40%
# 221                    -0.10%
# 222                    -0.30%
# 223                    -0.20%
# 224                     0.00%
# 225                     0.00%
# 226                     0.10%
# 227                     0.20%
# 228                     0.30%
# 229                     0.10%
# 230                    -0.10%
# 231                     0.20%
# 232                     0.40%
# 233                     0.60%
# 234                     0.90%
# 235                     1.10%
# 236                     1.20%
# 237                     1.30%
# 238                     1.40%
# 239                     2.00%
# 240                     2.50%
# 241                     4.00%
# 242                     5.10%
# 243                     5.40%
# 244                     4.90%
# 245                     3.80%
# 246                     2.70%
# 247                     2.50%
# 248                     2.60%
# 249                     2.50%
# 250                     2.80%
# 251                     3.40%
# 252                     4.30%
# 253                     3.90%
# 254                     2.50%
# 255                     0.00%
# 256                    -1.90%
# 257                    -2.70%
# 258                    -2.80%
# 259                    -2.80%
# 260                    -3.60%
# 261                    -3.90%
#
# [60 rows x 21 columns]

# %%
austin_2018_2022.columns
# Out:
# Index(['City', 'State', 'Month of Period End', 'Median Sale Price',
#        'Median Sale Price MoM ', 'Median Sale Price YoY ', 'Homes Sold',
#        'Homes Sold MoM ', 'Homes Sold YoY ', 'New Listings',
#        'New Listings MoM ', 'New Listings YoY ', 'Inventory', 'Inventory MoM ',
#        ' Inventory YoY ', 'Days on Market', 'Days on Market MoM',
#        'Days on Market YoY', 'Average Sale To List',
#        'Average Sale To List MoM ', 'Average Sale To List YoY '],
#       dtype='object')

# %%
#Test line graph using just austin data to get formatting and test other graph properties
import matplotlib
plt.figure(figsize= (50,20))
plt.plot(austin_2018_2022["Month of Period End"], austin_2018_2022["Median Sale Price"], marker="s", linewidth=3, color= "coral")
plt.xticks(austin_2018_2022["Month of Period End"], rotation=90, fontsize= 18)
matplotlib.rc("ytick", labelsize=18)
plt.xlabel("Months", fontsize = 20, fontweight= "bold")
plt.ylabel("Median Home Price (K)", fontsize = 20, fontweight= "bold")
plt.xlim("Jan-18", "Dec-22")
plt.show()

# %%
#Create line graph that contains both Austin and Dallas median sale price for 2012-2022
import matplotlib
plt.figure(figsize= (50,20))
plt.plot(austin_2018_2022["Month of Period End"], austin_2018_2022["Median Sale Price"], marker="s", linewidth=3, color= "coral", label= "Austin, TX")
plt.plot(dallas_2018_2022["Month of Period End"], dallas_2018_2022["Median Sale Price"], marker= "o", linewidth=3, color= "midnightblue", label= "Dallas, TX")
plt.xticks(austin_2018_2022["Month of Period End"], rotation=90, fontsize= 18)
matplotlib.rc("ytick", labelsize=18)
plt.xlabel("Months", fontsize = 20, fontweight= "bold")
plt.ylabel("Median Sale Price (K)", fontsize = 20, fontweight= "bold")
plt.xlim("Jan-18", "Dec-22")
plt.legend(fontsize= "25", loc = "lower right")
plt.title("Median Sale Price: Homes in Austin vs Dallas 2018 to 2022", fontsize=20, fontweight="bold")
plt.show()

# %%
#Clean up columns
#Get rid of commas in Inventory column
austin_2018_2022["Inventory"] = austin_2018_2022["Inventory"].str.replace(",", "")
#Convert columns to integers
austin_2018_2022["Inventory"] = austin_2018_2022["Inventory"].astype(int)

#Get rid of commas in Inventory column
dallas_2018_2022["Inventory"] = dallas_2018_2022["Inventory"].str.replace(",", "")
#Convert columns to integers
dallas_2018_2022["Inventory"] = dallas_2018_2022["Inventory"].astype(int)

#Convert columns to integers
austin_2018_2022["Days on Market"] = austin_2018_2022["Days on Market"].astype(int)

#Convert columns to integers
dallas_2018_2022["Days on Market"] = dallas_2018_2022["Days on Market"].astype(int)

#Get rid of '%' sign in Average Sale to List column
austin_2018_2022["Average Sale To List"] = austin_2018_2022["Average Sale To List"].str.replace("%", "")
#Convert column to integers
austin_2018_2022["Average Sale To List"] = austin_2018_2022["Average Sale To List"].astype(float)

#Get rid of '%' sign in Average Sale to List column
dallas_2018_2022["Average Sale To List"] = dallas_2018_2022["Average Sale To List"].str.replace("%", "")
#Convert column to integers
dallas_2018_2022["Average Sale To List"] = dallas_2018_2022["Average Sale To List"].astype(float)

# %%
#Create line graph that contains both Austin and Dallas Inventory numbers for 2012-2022
import matplotlib
plt.figure(figsize= (50,20))
plt.plot(austin_2018_2022["Month of Period End"], austin_2018_2022["Inventory"], marker="s", linewidth=3, color= "coral", label= "Austin, TX")
plt.plot(dallas_2018_2022["Month of Period End"], dallas_2018_2022["Inventory"], marker= "o", linewidth=3, color= "midnightblue", label= "Dallas, TX")
plt.xticks(austin_2018_2022["Month of Period End"], rotation=90, fontsize= 18)
matplotlib.rc("ytick", labelsize=18)
plt.xlabel("Months", fontsize = 20, fontweight= "bold")
plt.ylabel("Inventory", fontsize = 20, fontweight= "bold")
plt.xlim("Jan-18", "Dec-22")
plt.legend(fontsize= "25", loc = "lower right")
plt.title("Inventory: Homes in Austin vs Dallas 2018 to 2022", fontsize=20, fontweight="bold")
plt.show()

# %%
#Create line graph that contains both Austin and Dallas Days on Market numbers for 2012-2022
import matplotlib
plt.figure(figsize= (50,20))
plt.plot(austin_2018_2022["Month of Period End"], austin_2018_2022["Days on Market"], marker="s", linewidth=3, color= "coral", label= "Austin, TX")
plt.plot(dallas_2018_2022["Month of Period End"], dallas_2018_2022["Days on Market"], marker= "o", linewidth=3, color= "midnightblue", label= "Dallas, TX")
plt.xticks(austin_2018_2022["Month of Period End"], rotation=90, fontsize= 18)
matplotlib.rc("ytick", labelsize=18)
plt.xlabel("Months", fontsize = 20, fontweight= "bold")
plt.ylabel("Median Days on Market", fontsize = 20, fontweight= "bold")
plt.xlim("Jan-18", "Dec-22")
plt.legend(fontsize= "25", loc = "lower right")
plt.title("Median Days on Market: Homes in Austin vs Dallas 2018 to 2022", fontsize=20, fontweight="bold")
plt.show()

# %%
#Create line graph that contains both Austin and Dallas Average Sale to List numbers for 2012-2022
import matplotlib
plt.figure(figsize= (50,20))
plt.plot(austin_2018_2022["Month of Period End"], austin_2018_2022["Average Sale To List"], marker="s", linewidth=3, color= "coral", label= "Austin, TX")
plt.plot(dallas_2018_2022["Month of Period End"], dallas_2018_2022["Average Sale To List"], marker= "o", linewidth=3, color= "midnightblue", label= "Dallas, TX")
plt.xticks(austin_2018_2022["Month of Period End"], rotation=90, fontsize= 18)
matplotlib.rc("ytick", labelsize=18)
plt.xlabel("Months", fontsize = 20, fontweight= "bold")
plt.ylabel("Average Sale to List (%)", fontsize = 20, fontweight= "bold")
plt.xlim("Jan-18", "Dec-22")
plt.legend(fontsize= "25", loc = "lower right")
plt.title("Average Sale to List (%): Homes in Austin vs Dallas 2018 to 2022", fontsize=20, fontweight="bold")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Inventory vs Median Sale Price Linear Regression Plot
# ###### Does housing price increase when inventory decreases?

# %%
austin_2018_2022["Inventory"].describe()
# Out:
# count       60.000000
# mean      6635.200000
# std       1958.958914
# min       3049.000000
# 25%       5661.750000
# 50%       6619.500000
# 75%       8018.250000
# max      10827.000000
# Name: Inventory, dtype: float64

# %%
import scipy.stats as st
#Linear regression for Austin
x_values = austin_2018_2022["Inventory"]
y_values = austin_2018_2022["Median Sale Price"]
#Add linear regression equation to plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.figure(figsize=(20,15))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(4000, 300),fontsize=20,color="red")
plt.xlabel("Inventory", fontsize = 20, fontweight= "bold")
plt.ylabel("Median Sale Price (K)", fontsize = 20, fontweight= "bold")
plt.title("Linear Regression on Median Sale Price (K) for Inventory in Austin", fontsize = 20, fontweight= "bold")
print(f"The r-squared is: {rvalue**2}")
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The r-squared is: 0.016148557922311284
# The correlation between both factors is -0.13

# %%
dallas_2018_2022["Inventory"].describe()
# Out:
# count       60.000000
# mean     13343.266667
# std       4611.652896
# min       5002.000000
# 25%       9169.000000
# 50%      13920.000000
# 75%      16914.500000
# max      20883.000000
# Name: Inventory, dtype: float64

# %%
import scipy.stats as st
#Linear regression for Dallas
x_values = dallas_2018_2022["Inventory"]
y_values = dallas_2018_2022["Median Sale Price"]
#Add linear regression equation to plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.figure(figsize=(20,15))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6000, 275),fontsize=20,color="red")
plt.xlabel("Inventory", fontsize = 20, fontweight= "bold")
plt.ylabel("Median Sale Price (K)", fontsize = 20, fontweight= "bold")
plt.title("Linear Regression on Median Sale Price (K) for Inventory in Dallas", fontsize = 20, fontweight= "bold")
print(f"The r-squared is: {rvalue**2}")
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The r-squared is: 0.39554686201731126
# The correlation between both factors is -0.63

# %% [markdown]
# Discussion about the linear relationship for Inventory vs Median Sale Price (K):
# * When using the data from January 2018 to December 2022 in Austin there does not seem to a relationship (positive or negative) between housing availability (Inventory) and Median Sale Price. It may be expected that the less homes that are available, the higher the sale price would be, however the plot and r-squared value (0.016148557922311284) show that there is no correlation between these two factors in the Austin metro area for the given time frame. This may be due to other factors not available in this data set, such as new residential construction rates in the area for a given year or population influxes for the given time period.
# * In the Dallas metro area between January 2018 and December 2022 there is a moderate correlation between Inventory and Median Sale Price. As the number of active listings decreases, the price of the home increases. Again, there may be other factors that could also help give more insight into the changes in Median Sale Price, such as changes in population to the Dallas metro area.
# * It should be noted that during the given time frame, Dallas' lowest inventory point was 5002, while Austin's lowest is 3049. Given that the Dallas metro area - 15,600 sq. miles, is bigger than Austin's - 4,279 sq. miles, there are more homes available in the Dallas metro area because it covers a larger area.
# * ?When using two of the factors to determine which housing market is hotter, Austin appears to be more in demand based on comparing Inventory vs Median Sale Price. While Dallas metro area shows that having less housing availability will increase sale prices, Austin sale prices show more of a cluster around the same price point (~300-350K), which could mean that people are still willing to pay higher prices in Austin, even with average inventory.

# %% [markdown]
# #### Days on Market vs Median Sale Price Linear Regression Plot
# ###### Does sale price decrease with longer market time?

# %%
austin_2018_2022["Days on Market"].describe()
# Out:
# count    60.000000
# mean     34.033333
# std      11.605035
# min      16.000000
# 25%      25.000000
# 50%      32.500000
# 75%      40.000000
# max      70.000000
# Name: Days on Market, dtype: float64

# %%
dallas_2018_2022["Days on Market"].describe()
# Out:
# count    60.000000
# mean     33.933333
# std      12.747704
# min      14.000000
# 25%      22.000000
# 50%      33.000000
# 75%      41.250000
# max      60.000000
# Name: Days on Market, dtype: float64

# %%
import scipy.stats as st
#Linear regression for Austin
x_values = austin_2018_2022["Days on Market"]
y_values = austin_2018_2022["Median Sale Price"]
#Add linear regression equation to plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.figure(figsize=(10,10))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 325),fontsize=20,color="red")
plt.xlabel("Median Days on Market", fontsize = 20, fontweight= "bold")
plt.ylabel("Median Sale Price (K)", fontsize = 20, fontweight= "bold")
plt.title("Linear Regression on Median Sale Price (K) for Median Days on Market in Austin", fontsize = 16, fontweight= "bold")
print(f"The r-squared is: {rvalue**2}")
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The r-squared is: 0.002201506613273815
# The correlation between both factors is -0.05

# %%
import scipy.stats as st
#Linear regression for Dallas
x_values = dallas_2018_2022["Days on Market"]
y_values = dallas_2018_2022["Median Sale Price"]
#Add linear regression equation to plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)
plt.figure(figsize=(10,10))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20, 275),fontsize=20,color="red")
plt.xlabel("Median Days on Market", fontsize = 20, fontweight= "bold")
plt.ylabel("Median Sale Price (K)", fontsize = 20, fontweight= "bold")
plt.title("Linear Regression on Median Sale Price (K) for Median Days on Market in Dallas", fontsize = 16, fontweight= "bold")
print(f"The r-squared is: {rvalue**2}")
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The r-squared is: 0.54384665350525
# The correlation between both factors is -0.74

# %% [markdown]
# Discussion about the linear relationship for Median Days on Market vs Median Sale Price (K):
# * From 2018-2022 in the Austin metro area, there is no correlation between Median Sale Price and Median Days on the Market. Remaining on the market longer does not decrease the sale price of the home. This could mean that people are willing the pay the same price for a house no matter the length of the listing.
# * However, in the Dallas metro area there is a moderate correlation between Median Sale Price and Median Days on the Market. The longer a home stays on the market, the lower the sale price.
# * Both Austin and Dallas metro areas have almost identical average days on market times (34 and 33.9 days, respectively). Another factor that could be taken into consideration as to why these two markets differ in the correlation between Median Days on Market and Median Sale Price could be how many listings dropped their price for the given time period. Maybe home sellers in the Dallas area were more willing to drop their sale price versus in the Austin area.
